# %%
import requests as req
import pandas as pd
import os

url = 'https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/data/iris.csv'
data = req.get(url)
if not data.status_code == 200:
    print('get could not be secured.')
    exit(0)

# %% [markdown]
# print(data)
# print(type(data))
# for element in dir(data):
#     print(element)

# %%
os.makedirs('./datas/', exist_ok=True)
with open('./datas/' + os.path.basename(url), 'wb') as csv:
    csv.write(data.content)

# %%
csv = pd.read_csv('./datas/' + os.path.basename(url), encoding='utf-8')
csv.head(5)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # machine learning
# ## ---------------------------

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

FILE_PATH = './datas/iris.csv'
iris_data = pd.read_csv(FILE_PATH, encoding='utf=8')

# y: label
# x: training datas
y = iris_data.loc[:,"Name"]
x = iris_data.loc[:, list((iris_data.loc[0]).keys())[:-1]]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# 5            5.4         3.9          1.7         0.4
# 6            4.6         3.4          1.4         0.3
# 7            5.0         3.4          1.5         0.2
# 8            4.4         2.9          1.4         0.2
# 9            4.9         3.1          1.5         0.1
# 10           5.4         3.7          1.5         0.2
# 11           4.8         3.4          1.6         0.2
# 12           4.8         3.0          1.4         0.1
# 13           4.3         3.0          1.1         0.1
# 14           5.8         4.0          1.2         0.2
# 15           5.7         4.4          1.5         0.4
# ...

# %%
# split for training_data and test_data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,
                                                   train_size=0.8, shuffle=True)
clf = SVC()
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
score = accuracy_score(y_test, y_pred)
print('acc : ', score)
# Out:
# acc :  0.9666666666666667
# /usr/local/var/pyenv/versions/anaconda3-5.2.0/envs/ml/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# # 振り返り
# * SVC
# svmのカーネルトリックを用いた分類手法
# linearSVCもある
